# %%
class Bank:
    bankname = 'TIMES BANK'
    branch = 'Tirupathi Main Urban'

    def __init__(self, username, pannumber, mobile, address):
        self.username = username
        self.pannumber = pannumber
        self.mobile = mobile
        self.address = address
        self.balance = 0.0
        print('=' * 50)
        print(f'Hello {self.username}! Your account has been created successfully.')
        print('*' * 50)

    def deposit(self, amount):
        self.balance += amount
        print(f'{amount} deposited successfully.')

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f'{amount} withdrawn successfully.')
        else:
            print('Insufficient funds.')

    def ministatement(self):
        print(f'Your account balance is {self.balance}.')


print('*' * 50)
print(Bank.bankname)
print(Bank.branch)
print('*' * 50)

username = input('Enter your name: ')
pannumber = input('Enter your PAN number: ')
mobile = input('Enter your mobile number: ')
address = input('Enter your address: ')

b = Bank(username, pannumber, mobile, address)

while True:
    print('\nPlease select an option:')
    print('1. Deposit\n2. Withdraw\n3. Mini Statement\n4. Stop')
    option = int(input())

    if option == 1:
        amount = float(input('Enter deposit amount: '))
        b.deposit(amount)

    elif option == 2:
        amount = float(input('Enter withdrawal amount: '))
        b.withdraw(amount)

    elif option == 3:
        b.ministatement()

    elif option == 4:
        print('Thanks for using Times Bank.')
        break

    else:
        print('Invalid option. Please select a valid option.')
# Out:
# **************************************************
# TIMES BANK
# Tirupathi Main Urban
# **************************************************
# Enter your name: saia
# Enter your PAN number: nauuas
# Enter your mobile number: 152626
# Enter your address: adadadad
# ...
# Hello saia! Your account has been created successfully.
# **************************************************
#
# Please select an option:
# 1. Deposit
# 2. Withdraw
# 3. Mini Statement
# 4. Stop

# %%
#@1 OPTION 4
class Bank:
    bankname = 'TIMES BANK'
    branch = 'Tirupathi Main Urban'

    def __init__(self, username, pannumber, mobile, address):
        self.username = username
        self.pannumber = pannumber
        self.mobile = mobile
        self.address = address
        self.balance = 0.0
    print('=' * 50)
        print(f'Hello {self.username}! Your account has been created successfully.')
    print('*'* 50)
    
    def deposit(self, amount):
        self.balance += amount
        print(f'{amount} deposited successfully.')

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f'{amount} withdrawn successfully.')
        else:
            print('Insufficient funds.')

    def ministatement(self):
        print(f'Your account balance is {self.balance}.')

print('*' * 50)
print(Bank.bankname)
print(Bank.branch)
print('*' * 50)

username = input('Enter your name: ')
pannumber = input('Enter your PAN number: ')
mobile = input('Enter your mobile number: ')
address = input('Enter your address: ')

b = Bank(username, pannumber, mobile, address)

while True:
    print('\nPlease select an option:')
    print('1. Deposit\n2. Withdraw\n3. Mini Statement\n4. Stop')
    option = int(input())

    if option == 1:
        amount = float(input('Enter deposit amount: '))
        b.deposit(amount)

    elif option == 2:
        amount = float(input('Enter withdrawal amount: '))
        b.withdraw(amount)

    elif option == 3:
        b.ministatement()

    elif option == 4:
        print('Thanks for using Saravana Overseas Bank.')
        break

    else:
        print('Invalid option. Please select a valid option.')
# Out:
#   Cell In[1], line 13
#     print(f'Hello {self.username}! Your account has been created successfully.')
#     ^
# IndentationError: unexpected indent

# %%
class Bank:
    bankname = 'Saravana Overseas Bank'
    branch = 'Tirupathi Main Urban'

    def __init__(self, username, pannumber, mobile, address):
        self.username = username
        self.pannumber = pannumber
        self.mobile = mobile
        self.address = address
        self.balance = 0.0
        print(f'Hello {self.username}! Your account has been created successfully.')

    def deposit(self, amount):
        self.balance += amount
        print(f'{amount} deposited successfully.')

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f'{amount} withdrawn successfully.')
        else:
            print('Insufficient funds.')

    def ministatement(self):
        print(f'Your account balance is {self.balance}.')

b = Bank('m saravana', 'ABCDE1234F', '8317606962', ' tirupathi  Main Street')

while True:
    print('\nPlease select an option:')
    print('1. Deposit\n2. Withdraw\n3. Mini Statement\n4. Exit')
    option = int(input())

    if option == 1:
        amount = float(input('Enter deposit amount: '))
        b.deposit(amount)
    elif option == 2:
        amount = float(input('Enter withdrawal amount: '))
        b.withdraw(amount)
    elif option == 3:
        b.ministatement()
    elif option == 4:
        print('Thanks for using Saravana Overseas Bank.')
        break
    else:
        print('Invalid option. Please select a valid option.')
# Out:
# Hello m saravana! Your account has been created successfully.
#
# Please select an option:
# 1. Deposit
# 2. Withdraw
# 3. Mini Statement
# 4. Exit
# 1
# Enter deposit amount: 10000
# 10000.0 deposited successfully.
#
# Please select an option:
# 1. Deposit
# 2. Withdraw
# 3. Mini Statement
# 4. Exit
# 1
# Enter deposit amount: 5000
# 5000.0 deposited successfully.
#
# Please select an option:
# 1. Deposit
# 2. Withdraw
# 3. Mini Statement
# 4. Exit
# 2
# Enter withdrawal amount: 12000
# 12000.0 withdrawn successfully.
#
# Please select an option:
# 1. Deposit
# 2. Withdraw
# 3. Mini Statement
# 4. Exit
# 3
# Your account balance is 3000.0.
#
# Please select an option:
# 1. Deposit
# 2. Withdraw
# 3. Mini Statement
# 4. Exit
# 4
# Thanks for using Saravana Overseas Bank.

# %%
class Bank:
    bankname = 'TIMES BANK'
    branch = 'Tirupathi Main Urban'

    def __init__(self, username, pannumber, mobile, address):
        self.username = username
        self.pannumber = pannumber
        self.mobile = mobile
        self.address = address
        self.balance = 0.0
        print(f'Hello {self.username} Your account has been created successfully.')

    def deposit(self, amount):
        self.balance += amount
        print(f'{amount} deposited successfully.')

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f'{amount} withdrawn successfully.')
        else:
            print('Insufficient funds.')

    def ministatement(self):
        print(f'Your account balance is {self.balance}.')


print(f'Welcome to {Bank.bankname}, {Bank.branch}')

username = input('Enter your name: ')
pannumber = input('Enter your PAN number: ')
mobile = input('Enter your mobile number: ')
address = input('Enter your address: ')

b = Bank(username, pannumber, mobile, address)

while True:
    print('\nPlease select an option:')
    print('1. Deposit\n2. Withdraw\n3. Mini Statement\n4. Exit')
    option = int(input())

    if option == 1:
        amount = float(input('Enter deposit amount: '))
        b.deposit(amount)
    elif option == 2:
        amount = float(input('Enter withdrawal amount: '))
        b.withdraw(amount)
    elif option == 3:
        b.ministatement()
    elif option == 4:
        print('Thanks for using Saravana Overseas Bank.')
        break
    else:
        print('Invalid option. Please select a valid option.')
# Out:
# Welcome to TIMES BANK, Tirupathi Main Urban
# Enter your name: M SARAVANA
# Enter your PAN number: NYPPS2857R
# Enter your mobile number: 8317606962
# Enter your address: TIRUPATHI MAIN ROAD CHITTOOR
# Hello M SARAVANA! Your account has been created successfully.
#
# Please select an option:
# 1. Deposit
# 2. Withdraw
# 3. Mini Statement
# 4. Exit
# 1
# Enter deposit amount: 5000
# 5000.0 deposited successfully.
#
# Please select an option:
# 1. Deposit
# 2. Withdraw
# 3. Mini Statement
# 4. Exit
# 2
# Enter withdrawal amount: 2000
# 2000.0 withdrawn successfully.
#
# Please select an option:
# 1. Deposit
# 2. Withdraw
# 3. Mini Statement
# 4. Exit
# 3
# Your account balance is 3000.0.
#
# Please select an option:
# 1. Deposit
# 2. Withdraw
# 3. Mini Statement
# 4. Exit
# 5
# Invalid option. Please select a valid option.
#
# Please select an option:
# 1. Deposit
# 2. Withdraw
# 3. Mini Statement
# 4. Exit
# 4
# Thanks for using Saravana Overseas Bank.

# %%
class Bank:
    bankname = 'TIMES BANK'
    branch = 'Tirupathi Main Urban'
    account_holders = []  # Class-level variable to store account holder records

    def __init__(self, username, pannumber, mobile, address):
        self.username = username
        self.pannumber = pannumber
        self.mobile = mobile
        self.address = address
        self.balance = 0.0
        self.account_holders.append(self)  # Add current instance to account holder records
        print(f'Hello {self.username}! Your account has been created successfully.')

    def deposit(self, amount):
        self.balance += amount
        print(f'{amount} deposited successfully.')

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f'{amount} withdrawn successfully.')
        else:
            print('Insufficient funds.')

    def ministatement(self):
        print(f'Your account balance is {self.balance}.')


print(f'Welcome to {Bank.bankname}, {Bank.branch}')

username = input('Enter your name: ')
pannumber = input('Enter your PAN number: ')
mobile = input('Enter your mobile number: ')
address = input('Enter your address: ')

b = Bank(username, pannumber, mobile, address)

while True:
    print('\nPlease select an option:')
    print('1. Deposit\n2. Withdraw\n3. Mini Statement\n4. Exit')
    option = int(input())

    if option == 1:
        amount = float(input('Enter deposit amount: '))
        b.deposit(amount)
    elif option == 2:
        amount = float(input('Enter withdrawal amount: '))
        b.withdraw(amount)
    elif option == 3:
        b.ministatement()
    elif option == 4:
        print('Thanks for using Saravana Overseas Bank.')
        break
    else:
        print('Invalid option. Please select a valid option.')

print('\nAccount Holder Records:')
for account in Bank.account_holders:
    print(f'Username: {account.username}, PAN Number: {account.pannumber}, Mobile: {account.mobile}, Address: {account.address}')
# Out:
# Welcome to TIMES BANK, Tirupathi Main Urban
# Enter your name: M SARAVANA
# Enter your PAN number: NYPPS2857R
# Enter your mobile number: 8317606962
# Enter your address: TIRUPATHI
# Hello M SARAVANA! Your account has been created successfully.
#
# Please select an option:
# 1. Deposit
# 2. Withdraw
# 3. Mini Statement
# 4. Exit
# 1
# Enter deposit amount: 8000
# 8000.0 deposited successfully.
#
# Please select an option:
# 1. Deposit
# 2. Withdraw
# 3. Mini Statement
# 4. Exit
# 2
# Enter withdrawal amount: 5000
# 5000.0 withdrawn successfully.
#
# Please select an option:
# 1. Deposit
# 2. Withdraw
# 3. Mini Statement
# 4. Exit
# 5
# Invalid option. Please select a valid option.
#
# Please select an option:
# 1. Deposit
# 2. Withdraw
# 3. Mini Statement
# 4. Exit
# 3
# Your account balance is 3000.0.
#
# Please select an option:
# 1. Deposit
# 2. Withdraw
# 3. Mini Statement
# 4. Exit
# 4
# Thanks for using Saravana Overseas Bank.
#
# Account Holder Records:
# ...

# %%
class Bank:
    bankname = 'Saravana Overseas Bank'
    branch = 'Tirupathi Main Urban'
    account_holders = []

    def __init__(self, username, pannumber, mobile, address):
        self.username = username
        self.pannumber = pannumber
        self.mobile = mobile
        self.address = address
        self.balance = 0.0
        self.account_holders.append(self)
        print(f'Hello {self.username}! Your account has been created successfully.')

    def deposit(self, amount):
        self.balance += amount
        print(f'{amount} deposited successfully.')

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f'{amount} withdrawn successfully.')
        else:
            print('Insufficient funds.')

    def ministatement(self):
        print(f'Your account balance is {self.balance}.')

    @classmethod
    def view_customer_records(cls):
        print('\nCustomer Records:')
        for account in cls.account_holders:
            print(f'Username: {account.username}, PAN Number: {account.pannumber}, Mobile: {account.mobile}, Address: {account.address}')


print(f'Welcome to {Bank.bankname}, {Bank.branch}')

while True:
    print('\nPlease select an option:')
    print('1. Deposit\n2. Withdraw\n3. Mini Statement\n4. View Customer Records\n5. Exit')
    option = int(input())

    if option == 1:
        username = input('Enter your name: ')
        pannumber = input('Enter your PAN number: ')
        mobile = input('Enter your mobile number: ')
        address = input('Enter your address: ')

        b = Bank(username, pannumber, mobile, address)

        amount = float(input('Enter deposit amount: '))
        b.deposit(amount)

    elif option == 2:
        amount = float(input('Enter withdrawal amount: '))
        b.withdraw(amount)

    elif option == 3:
        b.ministatement()

    elif option == 4:
        Bank.view_customer_records()

    elif option == 5:
        print('Thanks for using Saravana Overseas Bank.')
        break

    else:
        print('Invalid option. Please select a valid option.')
# Out:
# Welcome to Saravana Overseas Bank, Tirupathi Main Urban
#
# Please select an option:
# 1. Deposit
# 2. Withdraw
# 3. Mini Statement
# 4. View Customer Records
# 5. Exit
# 1
# Enter your name: M SARAVANA
# Enter your PAN number: NYPPS 2857R
# Enter your mobile number: 8317606962
# Enter your address: TIRUPATHI
# Hello M SARAVANA! Your account has been created successfully.
# Enter deposit amount: 8000
# 8000.0 deposited successfully.
#
# Please select an option:
# 1. Deposit
# 2. Withdraw
# 3. Mini Statement
# 4. View Customer Records
# 5. Exit
# 1
# Enter your name: DAMU
# Enter your PAN number: NYPPS2857R
# Enter your mobile number: 8317606962
# Enter your address: TIRUPATHI
# Hello DAMU ! Your account has been created successfully.
# Enter deposit amount: 15000
# 15000.0 deposited successfully.
#
# Please select an option:
# 1. Deposit
# 2. Withdraw
# 3. Mini Statement
# 4. View Customer Records
# 5. Exit
# 4
#
# Customer Records:
# ...

# %%
# ADD OPTION 5  TO VIEW THE CUSTOMER RECORD
class Bank:
    bankname = ' TIMES BANK '
    branch = ' # 6-872-1-5 MAIN ROAD ,Tirupathi Main Urban'
    account_holders = []

    def __init__(self, username, pannumber, mobile, address):
        self.username = username
        self.pannumber = pannumber
        self.mobile = mobile
        self.address = address
        self.balance = 0.0
        self.account_holders.append(self)
        print(f'Hello {self.username}! Your account has been created successfully.')

    def deposit(self, amount):
        self.balance += amount
        print(f'{amount} deposited successfully.')

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f'{amount} withdrawn successfully.')
        else:
            print('Insufficient funds.')

    def ministatement(self):
        print(f'Your account balance is {self.balance}.')

    def view_customer_records(cls):
        print('\nCustomer Records:')
        for account in cls.account_holders:
            print(f'Username: {account.username}, PAN Number: {account.pannumber}, Mobile: {account.mobile}, Address: {account.address}')


print(f'Welcome to {Bank.bankname}, {Bank.branch}')

while True:
    print('\nPlease select an option:')
    #print('1. Deposit\n2. Withdraw\n3. Mini Statement\n4. View Customer Records\n5. Exit')
    print('1. Create an account\n2. Deposit\n3. Withdraw Money\n4. ministatement\n5.view Customer Records\n6. Exit')
    option = int(input())

    if option == 1:
        username = input('Enter your name: ')
        pannumber = input('Enter your PAN number: ')
        mobile = input('Enter your mobile number: ')
        address = input('Enter your address: ')

        b = Bank(username, pannumber, mobile, address)
        
    elif option==2:

        amount = float(input('Enter deposit amount: '))
        b.deposit(amount)

    elif option == 3:
        amount = float(input('Enter withdrawal amount: '))
        b.withdraw(amount)

    elif option == 4:
        b.ministatement()

    elif option == 5:
        Bank.view_customer_records()

    elif option == 6:
        print('Thanks for using Saravana Overseas Bank.')
        break

    else:
        print('Invalid option. Please select a valid option.')
# Out:
# Welcome to  TIMES BANK ,  # 6-872-1-5 MAIN ROAD ,Tirupathi Main Urban
#
# Please select an option:
# 1. Create an account
# 2. Deposit
# 3. Withdraw Money
# 4. ministatement
# 5.view Customer Records
# 6. Exit

# %%
class Bank:
    bankname = ' TIMES BANK '
    branch = ' # 6-872-1-5 MAIN ROAD ,Tirupathi Main Urban'
    account_holders = []

    def __init__(self, username, pannumber, mobile, address):
        self.username = username
        self.pannumber = pannumber
        self.mobile = mobile
        self.address = address
        self.balance = 0.0
        self.account_holders.append(self)
        print(f'Hello {self.username}! Your account has been created successfully.')

    def deposit(self, amount):
        self.balance += amount
        print(f'{amount} deposited successfully.')

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f'{amount} withdrawn successfully.')
        else:
            print('Insufficient funds.')

    def ministatement(self):
        print(f'Your account balance is {self.balance}.')

    def view_customer_records(cls):
        print('\nCustomer Records:')
        for account in cls.account_holders:
            print(f'Username: {account.username}, PAN Number: {account.pannumber}, Mobile: {account.mobile}, Address: {account.address}')


print(f'Welcome to {Bank.bankname}, {Bank.branch}')

while True:
    print('\nPlease select an option:')
    #print('1. Deposit\n2. Withdraw\n3. Mini Statement\n4. View Customer Records\n5. Exit')
    print('1. Create an account\n2. Deposit\n3. Withdraw Money\n4. ministatement\n5.view Customer Records\n6. Exit')
    option = int(input())

    if option == 1:
        username = input('Enter your name: ')
        pannumber = input('Enter your PAN number: ')
        mobile = input('Enter your mobile number: ')
        address = input('Enter your address: ')

        b = Bank(username, pannumber, mobile, address)
        
    elif option==2:

        amount = float(input('Enter deposit amount: '))
        b.deposit(amount)

    elif option == 3:
        amount = float(input('Enter withdrawal amount: '))
        b.withdraw(amount)

    elif option == 4:
        b.ministatement()

    elif option == 5:
        Bank.view_customer_records()

    elif option == 6:
        print('Thanks for using Saravana Overseas Bank.')
        break

    else:
        print('Invalid option. Please select a valid option.')
# Out:
# Welcome to  TIMES BANK ,  # 6-872-1-5 MAIN ROAD ,Tirupathi Main Urban
#
# Please select an option:
# 1. Create an account
# 2. Deposit
# 3. Withdraw Money
# 4. ministatement
# 5.view Customer Records
# 6. Exit
# 1
# Enter your name: sai
# Enter your PAN number: nypps2857r
# Enter your mobile number: 8317606962
# Enter your address: tirupathi
# Hello sai! Your account has been created successfully.
#
# Please select an option:
# 1. Create an account
# 2. Deposit
# 3. Withdraw Money
# 4. ministatement
# 5.view Customer Records
# 6. Exit
# 2
# Enter deposit amount: 15000
# 15000.0 deposited successfully.
#
# Please select an option:
# 1. Create an account
# 2. Deposit
# 3. Withdraw Money
# 4. ministatement
# 5.view Customer Records
# 6. Exit
# 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 64
#      61     b.ministatement()
#      63 elif option == 5:
# ...

# %%
###########6
class Bank:
    bankname = 'TIMES BANK'
    branch = '#6-872-1-5 MAIN ROAD, Tirupathi Main Urban'
    account_holders = []

    def __init__(self, username, pannumber, mobile, address):
        self.username = username
        self.pannumber = pannumber
        self.mobile = mobile
        self.address = address
        self.balance = 0.0
        self.account_holders.append(self)
        print(f'Hello {self.username}! Your account has been created successfully.')

    def deposit(self, amount):
        self.balance += amount
        print(f'{amount} deposited successfully.')

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f'{amount} withdrawn successfully.')
        else:
            print('Insufficient funds.')

    def ministatement(self):
        print(f'Your account balance is {self.balance}.')

    @classmethod
    def view_customer_records(cls):
        print('\nCustomer Records:')
        for account in cls.account_holders:
            print(f'Username: {account.username}, PAN Number: {account.pannumber}, Mobile: {account.mobile}, Address: {account.address}')


print(f'Welcome to {Bank.bankname}, {Bank.branch}')

while True:
    print('\nPlease select an option:')
    print('1. Create an account\n2. Deposit\n3. Withdraw Money\n4. Mini Statement\n5. View Customer Records\n6. Exit')
    option = int(input())

    if option == 1:
        username = input('Enter your name: ')
        pannumber = input('Enter your PAN number: ')
        mobile = input('Enter your mobile number: ')
        address = input('Enter your address: ')

        b = Bank(username, pannumber, mobile, address)
        
    elif option == 2:
        amount = float(input('Enter deposit amount: '))
        b.deposit(amount)

    elif option == 3:
        amount = float(input('Enter withdrawal amount: '))
        b.withdraw(amount)

    elif option == 4:
        b.ministatement()

    elif option == 5:
        Bank.view_customer_records()

    elif option == 6:
        print('Thanks for using Times Bank.')
        break

    else:
        print('Invalid option. Please select a valid option.')
# Out:
# Welcome to TIMES BANK, #6-872-1-5 MAIN ROAD, Tirupathi Main Urban
#
# Please select an option:
# 1. Create an account
# 2. Deposit
# 3. Withdraw Money
# 4. Mini Statement
# 5. View Customer Records
# 6. Exit
# 1
# Enter your name: M SARAVANA
# Enter your PAN number: NYPPS2857R
# Enter your mobile number: 8317606962
# Enter your address: TIRUPATHI MAIN ROAD ,CHITTOOR
# Hello M SARAVANA! Your account has been created successfully.
#
# Please select an option:
# 1. Create an account
# 2. Deposit
# 3. Withdraw Money
# 4. Mini Statement
# 5. View Customer Records
# 6. Exit
# 2
# Enter deposit amount: 18000
# 18000.0 deposited successfully.
#
# Please select an option:
# 1. Create an account
# 2. Deposit
# 3. Withdraw Money
# 4. Mini Statement
# 5. View Customer Records
# 6. Exit
# 3
# Enter withdrawal amount: 10000
# 10000.0 withdrawn successfully.
#
# Please select an option:
# 1. Create an account
# 2. Deposit
# 3. Withdraw Money
# 4. Mini Statement
# 5. View Customer Records
# 6. Exit
# ...

# %%
class Bank:
    bankname = 'TIMES BANK'
    branch = '#6-872-1-5 MAIN ROAD, Tirupathi Main Urban'
    account_holders = []
    account_number_counter = 1000  # Starting account number counter

    def __init__(self, username, pannumber, mobile, address):
        self.username = username
        self.pannumber = pannumber
        self.mobile = mobile
        self.address = address
        self.account_number = Bank.account_number_counter  # Assigning account number
        Bank.account_number_counter += 1  # Increment account number counter
        self.balance = 0.0
        Bank.account_holders.append(self)
        print(f'Hello {self.username}! Your account with account number {self.account_number} has been created successfully.')
        
    def deposit(self, amount):
        self.balance += amount
        print(f'{amount} deposited successfully.')

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f'{amount} withdrawn successfully.')
        else:
            print('Insufficient funds.')

    def ministatement(self):
        print(f'Your account balance is {self.balance}.')

    @classmethod
    def view_customer_records(cls):
        print('\nCustomer Records:')
        for account in cls.account_holders:
            print(f'Account Number: {account.account_number}, Username: {account.username}, PAN Number: {account.pannumber}, Mobile: {account.mobile}, Address: {account.address}')


print(f'Welcome to {Bank.bankname}, {Bank.branch}')

while True:
    print('\nPlease select an option:')
    print('1. Create an account\n2. Deposit\n3. Withdraw Money\n4. Mini Statement\n5. View Customer Records\n6. Exit')
    option = int(input())

    if option == 1:
        username = input('Enter your name: ')
        pannumber = input('Enter your PAN number: ')
        mobile = input('Enter your mobile number: ')
        address = input('Enter your address: ')
        
        b = Bank(username, pannumber, mobile, address)
        
    elif option == 2:
        amount = float(input('Enter deposit amount: '))
        b.deposit(amount)

    elif option == 3:
        amount = float(input('Enter withdrawal amount: '))
        b.withdraw(amount)

    elif option == 4:
        b.ministatement()

    elif option == 5:
        Bank.view_customer_records()

    elif option == 6:
        print('Thanks for using Times Bank.')
        break

    else:
        print('Invalid option. Please select a valid option.')
# Out:
# Welcome to TIMES BANK, #6-872-1-5 MAIN ROAD, Tirupathi Main Urban
#
# Please select an option:
# 1. Create an account
# 2. Deposit
# 3. Withdraw Money
# 4. Mini Statement
# 5. View Customer Records
# 6. Exit
# 1
# Enter your name: m saravana
# Enter your PAN number: nypps2857r
# Enter your mobile number: 831760692
# Enter your address: tirupathi
# Hello m saravana! Your account with account number 1000 has been created successfully.
#
# Please select an option:
# 1. Create an account
# 2. Deposit
# 3. Withdraw Money
# 4. Mini Statement
# 5. View Customer Records
# 6. Exit
# 1
# Enter your name: vinodh
# Enter your PAN number: nypps2857g
# Enter your mobile number: 8317606962
# Enter your address: tirupathi main chittoor
# Hello vinodh! Your account with account number 1001 has been created successfully.
#
# Please select an option:
# 1. Create an account
# 2. Deposit
# 3. Withdraw Money
# 4. Mini Statement
# 5. View Customer Records
# 6. Exit
# 5
#
# Customer Records:
# ...

# %%
class Bank:
    bankname = 'TIMES BANK'
    branch = 'Tirupathi Main Urban'

    def __init__(self, username, pannumber, mobile, address, pin_number):
        self.username = username
        self.pannumber = pannumber
        self.mobile = mobile
        self.address = address
        self.balance = 0.0
        self.pin_number = pin_number
        print('*' * 50)
        print(f'Hello {self.username}! Your account has been created successfully.')
        print('*' * 50)

    def deposit(self, amount):
        self.balance += amount
        print(f'{amount} deposited successfully.')

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f'{amount} withdrawn successfully.')
        else:
            print('Insufficient funds.')

    def ministatement(self):
        print(f'Your account balance is {self.balance}.')

    def withdraw_with_pin(self, pin, denomination):
        if pin == self.pin_number:
            if denomination <= self.balance:
                self.balance -= denomination
                print(f'Amount of {denomination} withdrawn successfully.')
            else:
                print('Insufficient funds.')
        else:
            print('Invalid PIN.')

print('*' * 50)
print(Bank.bankname)
print(Bank.branch)
print('*' * 50)

print('*')
username = input('Enter Customer Name: ')
pannumber = input('Enter your PAN number: ')
mobile = input('Enter your mobile number: ')
address = input('Enter your address: ')
pin_number = input('Enter your PIN number: ')

b = Bank(username, pannumber, mobile, address, pin_number)

while True:
    print('\nPlease select an option:')
    print('1. Deposit\n2. Withdraw\n3. Mini Statement\n4. Withdraw with PIN\n5. Stop')
    option = int(input())

    if option == 1:
        amount = float(input('Enter deposit amount: '))
        b.deposit(amount)

    elif option == 2:
        amount = float(input('Enter withdrawal amount: '))
        b.withdraw(amount)

    elif option == 3:
        b.ministatement()

    elif option == 4:
        pin = input('Enter PIN: ')
        denomination = float(input('Enter withdrawal amount: '))
        b.withdraw_with_pin(pin, denomination)

    elif option == 5:
        print('Thanks for using Times Bank.')
        break

    else:
        print('Invalid option. Please select a valid option.')
# Out:
# **************************************************
# TIMES BANK
# Tirupathi Main Urban
# **************************************************
# *
# Enter Customer Name: sas
# Enter your PAN number: sas
# Enter your mobile number: asa
# Enter your address: sas

# %%
class Bank:
    bankname = 'TIMES BANK'
    branch = ' Tirupathi Main Urban'
    account_holders = []
    account_number_counter = 1000  # Starting account number counter

    def __init__(self, username,pannumber, mobile, address, pin_number, initial_deposit):
        self.username = username
        self.pannumber = pannumber
        self.mobile = mobile
        self.address = address
        self.pin_number = pin_number
        self.balance = initial_deposit
        self.account_number = Bank.account_number_counter  # Assigning account number
        Bank.account_number_counter += 1  # Increment account number counter
        Bank.account_holders.append(self)
        print('=' * 80)
        print(f'Hello {self.username}! Your account with account number {self.account_number} has been created successfully.')
        print('=' * 80) 
    def deposit(self, amount):
        self.balance += amount
        print(f'{amount} deposited successfully.')

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f'{amount} withdrawn successfully.')
        else:
            print('Insufficient funds.')
            
    def ministatement(self):
        print(f'Your account balance is {self.balance}.')

    @classmethod
    def view_customer_records(cls):
        print('\nCustomer Records:')
        for account in cls.account_holders:
            print(f'Account Number: {account.account_number}, Username: {account.username}, Balance: {account.balance}')

# Creating an account
print('=' * 50)
print(f'Welcome to {Bank.bankname}, {Bank.branch}')
print('=' * 50)
username = input('Enter your name: ')
pannumber = input('Enter your PAN number: ')
mobile = input('Enter your mobile number: ')
address = input('Enter your address: ')
pin_number = input('Enter your PIN number: ')
initial_deposit = float(input('Enter initial deposit amount: '))
#b = Bank(username, pin_number, initial_deposit)
b = Bank(username,pannumber, mobile, address, pin_number, initial_deposit)
while True:
    print('\nPlease select an option:')
    print('1. Create an account\n2. Deposit\n3. Withdraw Money\n4. Mini Statement\n5. View Customer Records\n6. Exit')
    option = int(input())

    if option == 1:
        username = input('Enter your name: ')
        pannumber = input('Enter your PAN number: ')
        mobile = input('Enter your mobile number: ')
        address = input('Enter your address: ')
        pin_number = input('Enter your PIN number: ')
        initial_deposit = float(input('Enter initial deposit amount: '))
        b = Bank(username,pannumber, mobile, address, pin_number, initial_deposit)
        
    elif option == 2:
        amount = float(input('Enter deposit amount: '))
        b.deposit(amount)

    elif option == 3:
        amount = float(input('Enter withdrawal amount: '))
        b.withdraw(amount)

    elif option == 4:
        b.ministatement()

    elif option == 5:
        Bank.view_customer_records()

    elif option == 6:
        print('Thanks for using Times Bank.')
        break

    else:
        print('Invalid option. Please select a valid option.')
# Out:
# ...
# Welcome to TIMES BANK,  Tirupathi Main Urban
# ...
# Enter your name: sai
# Enter your PAN number: saasa
# Enter your mobile number: saa
# Enter your address: asass
# Enter your PIN number: asasa
# Enter initial deposit amount: asas
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 49
#      47 address = input('Enter your address: ')
#      48 pin_number = input('Enter your PIN number: ')
# ---> 49 initial_deposit = float(input('Enter initial deposit amount: '))
#      50 #b = Bank(username, pin_number, initial_deposit)
#      51 b = Bank(username,pannumber, mobile, address, pin_number, initial_deposit)
#
# ValueError: could not convert string to float: 'asas'
